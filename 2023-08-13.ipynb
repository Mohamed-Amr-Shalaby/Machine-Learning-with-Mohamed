# %% [markdown]
# # Libraries

# %%
import pandas as pd                 # pandas is a dataframe library
import numpy as np                  # numpy is a mathematical library
import matplotlib.pyplot as plt     # matplotlib.pyplot draw grphs

# %%
x = [1,2,3]
y = [1,2,3]

z = []

for  i in range(len(x)):
    z.append(x[i] * y[i])

y = sum(z)

# %%
x = np.array([1,2,3])
y = np.array([1,2,3])

y = np.matmul(x.transpose(), y) # 1*1 + 2*2 + 3*3

df = pd.read_csv('2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv')

df.info()

#Got the schema, now clear all the columns that have a large number of null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
# ...

# %%
df.describe()
# Out:
#                  X            Y          Date  Hectare Squirrel Number
# count  3023.000000  3023.000000  3.023000e+03              3023.000000
# mean    -73.967184    40.780853  1.011949e+07                 4.123718
# std       0.007726     0.010285  4.246671e+04                 3.096492
# min     -73.981159    40.764911  1.006202e+07                 1.000000
# 25%     -73.973102    40.771676  1.008202e+07                 2.000000
# 50%     -73.968594    40.778166  1.012202e+07                 3.000000
# 75%     -73.960189    40.791219  1.014202e+07                 6.000000
# max     -73.949722    40.800119  1.020202e+07                23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
# ...

# %%
df.drop(['Color notes', 'Other Interactions', 'Other Activities', 'Specific Location'], axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 27 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# X                                                0
# Y                                                0
# Unique Squirrel ID                               0
# Hectare                                          0
# Shift                                            0
# Date                                             0
# Hectare Squirrel Number                          0
# Age                                            121
# Primary Fur Color                               55
# Highlight Fur Color                           1086
# Combination of Primary and Highlight Color       0
# Location                                        64
# Above Ground Sighter Measurement               114
# Running                                          0
# Chasing                                          0
# Climbing                                         0
# Eating                                           0
# Foraging                                         0
# ...

# %%
df.drop(['Highlight Fur Color'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Combination of Primary and Highlight Color  3023 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# X                                               0
# Y                                               0
# Unique Squirrel ID                              0
# Hectare                                         0
# Shift                                           0
# Date                                            0
# Hectare Squirrel Number                         0
# Age                                           121
# Primary Fur Color                              55
# Combination of Primary and Highlight Color      0
# Location                                       64
# Above Ground Sighter Measurement              114
# Running                                         0
# Chasing                                         0
# Climbing                                        0
# Eating                                          0
# Foraging                                        0
# Kuks                                            0
# Quaas                                           0
# ...

# %%
df.head(10)
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# 5 -73.968361  40.772591     11H-AM-1010-03     11H    AM  10102018
# 6 -73.954120  40.793181     36H-AM-1010-02     36H    AM  10102018
# 7 -73.958269  40.791737     33F-AM-1008-02     33F    AM  10082018
# 8 -73.967429  40.782972     21C-PM-1006-01     21C    PM  10062018
# 9 -73.972250  40.774288     11D-AM-1010-03     11D    AM  10102018
#
#    Hectare Squirrel Number    Age Primary Fur Color  \
# 0                        3    NaN               NaN
# 1                        4    NaN               NaN
# 2                        8    NaN              Gray
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# Adult       2568
# Juvenile     330
# ?              4
# Name: count, dtype: int64

# %%
df.dropna(axis=0, subset=['Age'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2902 entries, 3 to 3022
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           2902 non-null   float64
#  1   Y                                           2902 non-null   float64
#  2   Unique Squirrel ID                          2902 non-null   object
#  3   Hectare                                     2902 non-null   object
#  4   Shift                                       2902 non-null   object
#  5   Date                                        2902 non-null   int64
#  6   Hectare Squirrel Number                     2902 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2867 non-null   object
#  9   Combination of Primary and Highlight Color  2902 non-null   object
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# Adult       2568
# Juvenile     330
# ?              4
# Name: count, dtype: int64

# %%
df.dropna(axis = 0, how = 'any', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2784 entries, 6 to 3022
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           2784 non-null   float64
#  1   Y                                           2784 non-null   float64
#  2   Unique Squirrel ID                          2784 non-null   object
#  3   Hectare                                     2784 non-null   object
#  4   Shift                                       2784 non-null   object
#  5   Date                                        2784 non-null   int64
#  6   Hectare Squirrel Number                     2784 non-null   int64
#  7   Age                                         2784 non-null   object
#  8   Primary Fur Color                           2784 non-null   object
#  9   Combination of Primary and Highlight Color  2784 non-null   object
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# Adult       2470
# Juvenile     312
# Name: count, dtype: int64

# %%
df[df['Age'] == '?']
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 2593 -73.963881  40.792371     32A-PM-1013-02     32A    PM  10132018
# 2776 -73.981084  40.768791      2A-PM-1019-05     02A    PM  10192018
#
#       Hectare Squirrel Number Age Primary Fur Color  \
# 2593                        2   ?              Gray
# 2776                        5   ?              Gray
#
#      Combination of Primary and Highlight Color  ... Foraging   Kuks  Quaas  \
# 2593                                 Gray+White  ...     True  False  False
# 2776                                      Gray+  ...    False  False  False
#
#       Moans  Tail flags  Tail twitches  Approaches  Indifferent  Runs from  \
# 2593  False       False          False       False         True      False
# 2776  False       False          False       False        False      False
#
#                                           Lat/Long
# 2593  POINT (-73.9638812060405 40.792371494142905)
# ...

# %%
df = df.drop(df[df['Age'] == '?'].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2782 entries, 6 to 3022
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           2782 non-null   float64
#  1   Y                                           2782 non-null   float64
#  2   Unique Squirrel ID                          2782 non-null   object
#  3   Hectare                                     2782 non-null   object
#  4   Shift                                       2782 non-null   object
#  5   Date                                        2782 non-null   int64
#  6   Hectare Squirrel Number                     2782 non-null   int64
#  7   Age                                         2782 non-null   object
#  8   Primary Fur Color                           2782 non-null   object
#  9   Combination of Primary and Highlight Color  2782 non-null   object
# ...

# %%
df['Combination of Primary and Highlight Color'].value_counts()
# Out:
# Combination of Primary and Highlight Color
# Gray+                          833
# Gray+Cinnamon                  691
# Gray+White                     458
# Gray+Cinnamon, White           257
# Cinnamon+Gray                  155
# Cinnamon+White                  89
# Black+                          70
# Cinnamon+                       58
# Cinnamon+Gray, White            56
# Gray+Black, Cinnamon, White     30
# Gray+Black                      24
# Black+Cinnamon                  15
# Cinnamon+Black                  10
# Gray+Black, Cinnamon             9
# Black+Gray                       8
# Gray+Black, White                7
# Black+Cinnamon, White            3
# Cinnamon+Black, White            3
# Cinnamon+Gray, Black             3
# Black+White                      2
# Black+Gray, White                1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# X                                             float64
# Y                                             float64
# Unique Squirrel ID                             object
# Hectare                                        object
# Shift                                          object
# Date                                            int64
# Hectare Squirrel Number                         int64
# Age                                            object
# Primary Fur Color                              object
# Combination of Primary and Highlight Color     object
# Location                                       object
# Above Ground Sighter Measurement               object
# Running                                          bool
# Chasing                                          bool
# Climbing                                         bool
# Eating                                           bool
# Foraging                                         bool
# ...

# %%
cats = ['Hectare', 'Shift', 'Age', 'Primary Fur Color', 'Combination of Primary and Highlight Color', 'Location', 'Above Ground Sighter Measurement']
for colName in cats:
    mappingCats = {cat : i for i,cat in enumerate(df[colName].unique())}
    print(mappingCats)
    df[colName] = df[colName].apply(lambda x: mappingCats[x])
bools = ['Running', 'Chasing', 'Climbing', 'Eating', 'Foraging', 'Kuks', 'Quaas', 'Moans', 'Tail flags', 'Tail twitches', 'Approaches', 'Indifferent', 'Runs from']
for colName in bools:
    mappingBools = {True : 1, False : 0}
    print(mappingBools)
    df[colName] = df[colName].apply(lambda x: mappingBools[x])
# Out:
# {'36H': 0, '33F': 1, '21C': 2, '11D': 3, '20B': 4, '22F': 5, '36I': 6, '05C': 7, '07H': 8, '16C': 9, '14E': 10, '32A': 11, '17F': 12, '16I': 13, '12I': 14, '32F': 15, '15E': 16, '39G': 17, '07E': 18, '17C': 19, '10A': 20, '28A': 21, '12B': 22, '18A': 23, '33H': 24, '29C': 25, '38C': 26, '31H': 27, '08H': 28, '34F': 29, '13H': 30, '32E': 31, '35C': 32, '17E': 33, '02B': 34, '19D': 35, '40B': 36, '03E': 37, '39C': 38, '06G': 39, '14F': 40, '06I': 41, '15F': 42, '08B': 43, '03A': 44, '05E': 45, '05F': 46, '11B': 47, '16E': 48, '29H': 49, '23C': 50, '33C': 51, '38G': 52, '16G': 53, '35A': 54, '28C': 55, '32D': 56, '22A': 57, '19C': 58, '15G': 59, '10F': 60, '42E': 61, '22B': 62, '05A': 63, '41D': 64, '21G': 65, '07F': 66, '38F': 67, '41B': 68, '31A': 69, '42G': 70, '37D': 71, '37E': 72, '07G': 73, '15I': 74, '19B': 75, '13D': 76, '35B': 77, '40D': 78, '38B': 79, '40I': 80, '07B': 81, '40A': 82, '03B': 83, '21D': 84, '10B': 85, '13E': 86, '41A': 87, '02F': 88, '26A': 89, '35E': 90, '11G':
# ...

# %%
#Since an ID is not necessary in learning about the general behavior of squirrels, and I don't see a way to use it to predict the behavior of other squirrels, I will drop it.
df.drop('Unique Squirrel ID', axis=1, inplace=True)

# %%
df.drop('Lat/Long', axis=1, inplace=True)

# %%
df
# Out:
#               X          Y  Hectare  Shift      Date  Hectare Squirrel Number  \
# 6    -73.954120  40.793181        0      0  10102018                        2
# 7    -73.958269  40.791737        1      0  10082018                        2
# 8    -73.967429  40.782972        2      1  10062018                        1
# 9    -73.972250  40.774288        3      0  10102018                        3
# 10   -73.969506  40.782351        4      1  10132018                        5
# ...         ...        ...      ...    ...       ...                      ...
# 3017 -73.964544  40.781160      190      1  10182018                        2
# 3018 -73.963943  40.790868      152      0  10072018                        4
# 3019 -73.970402  40.782560      295      1  10132018                        5
# 3020 -73.966587  40.783678      130      1  10122018                        7
# 3022 -73.975479  40.769640       45      1  10122018                        1
#
# ...
